# %% [markdown]
# # 📊 **MEU PRIMEIRO DASHBOARD** ❤
#
# _______

# %% [markdown]
# ## Meu primeiro relatório para portfólio foi criado com uma base de dados fictícia fornecida pelo **MINI CURSO DE POWER BI** do *Leonardo Karpinski*.

# %% [markdown]
# ### 📚 Estou iniciando os estudos em Power BI e esse meu primeiro projeto mostra uma análise feita para uma empresa fictícia do setor de alimentos e bebidas.
#
# ----
#
# ### 🎯 O objetivo do curso era criar um dashboard do zero em um mini curso de poucas horas, sendo assim, a base já veio pronta para gerar o relatório, sem a necessidade de limpeza e manipulação dos dados.

# %% [markdown]
# Abaixo segue o relatório final que serviu de modelo e cujo plano de fundo foi fornecido para fazer nosso relatório:
#
# ![modelo karpinski.png](data:image/png;base64,...)

# %% [markdown]
# ## Porém, eu mesma quis criar meus planos de fundo no PPT (dark e light), para ir praticando e poder desenvolver meu design próprio, usando o modelo apenas como inspiração. Seguem abaixo: ❤

# %% [markdown]
# ![dashboard_minicurso_LK_DARK.png](data:image/png;base64,...)

# %% [markdown]
# ![dashboard_minicurso_LK_LIGHT.png](data:image/png;base64,...)

# %% [markdown]
# ### O relatório tinha como objetivo fazer a análise de RECEITA, CUSTO e MARGEM por grupo de produto, produto, vendedor e supervisor e evolução temporal.
